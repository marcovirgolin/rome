# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeng01/rome/blob/main/notebooks/causal_trace.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/rome
# git clone https://github.com/kmeng01/rome rome > install.log 2>&1
# pip install -r /content/rome/scripts/colab_reqs/rome.txt >> install.log 2>&1
# pip install --upgrade google-cloud-storage >> install.log 2>&1
# Out:
# bash: line 2: cd: /content: No such file or directory

# %%
IS_COLAB = False
try:
    import google.colab, torch, os

    IS_COLAB = True
    os.chdir("/content/rome")
    if not torch.cuda.is_available():
        raise Exception("Change runtime type to include a GPU.")
except ModuleNotFoundError as _:
    pass

# %% [markdown]
# ## Causal Tracing
#
# A demonstration of the double-intervention causal tracing method.
#
# The strategy used by causal tracing is to understand important
# states within a transfomer by doing two interventions simultaneously:
#
# 1. Corrupt a subset of the input.  In our paper, we corrupt the subject tokens
#    to frustrate the ability of the transformer to accurately complete factual
#    prompts about the subject.
# 2. Restore a subset of the internal hidden states.  In our paper, we scan
#    hidden states at all layers and all tokens, searching for individual states
#    that carry the necessary information for the transformer to recover its
#    capability to complete the factual prompt.
#
# The traces of decisive states can be shown on a heatmap.  This notebook
# demonstrates the code for conducting causal traces and creating these heatmaps.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The `experiments.causal_trace` module contains a set of functions for running causal traces.
#
# In this notebook, we reproduce, demonstrate and discuss the interesting functions.
#
# We begin by importing several utility functions that deal with tokens and transformer models.

# %%
import os, re, json
import torch, numpy
from collections import defaultdict
from util import nethook
from util.globals import DATA_DIR
from experiments.causal_trace import (
    ModelAndTokenizer,
    layername,
    guess_subject,
    plot_trace_heatmap,
)
from experiments.causal_trace import (
    make_inputs,
    decode_tokens,
    find_token_range,
    predict_token,
    predict_from_input,
    collect_embedding_std,
)
from dsets import KnownsDataset

torch.set_grad_enabled(False)

# %% [markdown]
# Now we load a model and tokenizer, and show that it can complete a couple factual statements correctly.

# %%
model_name = "gpt2"  # or "EleutherAI/gpt-j-6B" or "EleutherAI/gpt-neox-20b"
mt = ModelAndTokenizer(
    model_name,
    low_cpu_mem_usage=True,
    torch_dtype=torch.float32 #(torch.float16 if "20b" in model_name else None),
)

# %%
predict_token(
    mt,
    ["Megan Rapinoe plays the sport of", "The Space Needle is in the city of"],
    return_p=True,
)
# Out:
# /Users/marco/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor_str.py:115: UserWarning: The operator 'aten::nonzero' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/mps/MPSFallback.mm:11.)
#   nonzero_finite_vals = torch.masked_select(
# ([' football', ' San'], tensor([0.0381, 0.0127], device='mps:0'))

# %% [markdown]
# To obfuscate the subject during Causal Tracing, we use noise sampled from a zero-centered spherical Gaussian, whose stddev is 3 times the $\sigma$ stddev the model's embeddings. Let's compute that value.

# %%
knowns = KnownsDataset(DATA_DIR)  # Dataset of known facts
#noise_level = 3 * collect_embedding_std(mt, [k["subject"] for k in knowns])
noise_level = 0.4033433049917221 # for gpt2 
print(f"Using noise level {noise_level}")
# Out:
# Loaded dataset with 1209 elements
# Using noise level 0.4033433049917221

# %% [markdown]
# ## Tracing a single location
#
# The core intervention in causal tracing is captured in this function:
#
# `trace_with_patch` a single causal trace.
#
# It enables running a batch of inferences with two interventions.
#
#   1. Random noise can be added to corrupt the inputs of some of the batch.
#   2. At any point, clean non-noised state can be copied over from an
#      uncorrupted batch member to other batch members.
#
# The convention used by this function is that the zeroth element of the
# batch is the uncorrupted run, and the subsequent elements of the batch
# are the corrupted runs.  The argument tokens_to_mix specifies an
# be corrupted by adding Gaussian noise to the embedding for the batch
# inputs other than the first element in the batch.  Alternately,
# subsequent runs could be corrupted by simply providing different
# input tokens via the passed input batch.
#
# To ensure that corrupted behavior is representative, in practice, we
# will actually run several (ten) corrupted runs in the same batch,
# each with its own sample of noise.
#
# Then when running, a specified set of hidden states will be uncorrupted
# by restoring their values to the same vector that they had in the
# zeroth uncorrupted run.  This set of hidden states is listed in
# states_to_patch, by listing [(token_index, layername), ...] pairs.
# To trace the effect of just a single state, this can be just a single
# token/layer pair.  To trace the effect of restoring a set of states,
# any number of token indices and layers can be listed.
#
# Note that this function is also in experiments.causal_trace; the code
# is shown here to show the logic.

# %%
def trace_with_patch(
    model,  # The model
    inp,  # A set of inputs
    states_to_patch,  # A list of (token index, layername) triples to restore
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    trace_layers=None,  # List of traced outputs to return
):
    prng = numpy.random.RandomState(1)  # For reproducibility, use pseudorandom noise
    patch_spec = defaultdict(list)
    for t, l in states_to_patch:
        patch_spec[l].append(t)
    embed_layername = layername(model, 0, "embed")

    def untuple(x):
        return x[0] if isinstance(x, tuple) else x

    # Define the model-patching rule.
    def patch_rep(x, layer):
        if layer == embed_layername:
            # If requested, we corrupt a range of token embeddings on batch items x[1:]
            if tokens_to_mix is not None:
                b, e = tokens_to_mix
                noise_sampl = prng.randn(x.shape[0] - 1, e - b, x.shape[2])
                noise_sampl = noise_sampl.astype("float32") # otherwise M1 cries
                x[1:, b:e] += noise * torch.from_numpy(
                    noise_sampl
                ).to(x.device)
            return x
        if layer not in patch_spec:
            return x
        # If this layer is in the patch_spec, restore the uncorrupted hidden state
        # for selected tokens.
        h = untuple(x)
        for t in patch_spec[layer]:
            h[1:, t] = h[0, t]
        return x

    # With the patching rules defined, run the patched model in inference.
    additional_layers = [] if trace_layers is None else trace_layers
    with torch.no_grad(), nethook.TraceDict(
        model,
        [embed_layername] + list(patch_spec.keys()) + additional_layers,
        edit_output=patch_rep,
    ) as td:
        outputs_exp = model(**inp)

    # We report softmax probabilities for the answers_t token predictions of interest.
    probs = torch.softmax(outputs_exp.logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]

    # If tracing all layers, collect all activations together to return.
    if trace_layers is not None:
        all_traced = torch.stack(
            [untuple(td[layer].output).detach().cpu() for layer in trace_layers], dim=2
        )
        return probs, all_traced

    return probs

# %% [markdown]
# ## Below, the addition of the direct method
# The authors propose to (a) corrupt the net (add noise to the embedding of the input for the SUBJECT tokens) and (b) patch-back the state of interest.
# Another approach (direct) is to instead corrupt the state of interest, other things being equal.
#
# Now, to corrupt h^l_i, we don't know what is a commensurate noise for it. A strategy could be to run the net over many tokens and record std (similarly to how done for the inputs before). Another, is to "patch in" the clean net the corrupted state obtained from running on the corrupted input. I do the latter.

# %%
def trace_with_corrupt(
    model,  # The model
    inp,  # A set of inputs
    states_to_corrupt,  # A list of (token index, layername) triples to corrupt
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    trace_layers=None,  # List of traced outputs to return
):
    prng = numpy.random.RandomState(1)  # For reproducibility, use pseudorandom noise
    corr_spec = defaultdict(list)
    for t, l in states_to_corrupt:
        corr_spec[l].append(t)
    embed_layername = layername(model, 0, "embed")

    def untuple(x):
        return x[0] if isinstance(x, tuple) else x

    # Define the model-corruption rule.
    def corr_rep(x, layer):
        if layer == embed_layername and first_pass: # if it is the second pass, give clean inputs
            # If requested, we corrupt a range of token embeddings on batch items x[1:]
            if tokens_to_mix is not None:
                b, e = tokens_to_mix
                noise_sampl = prng.randn(x.shape[0] - 1, e - b, x.shape[2]).astype("float32")
                x[1:, b:e] += noise * torch.from_numpy(
                    noise_sampl
                ).to(x.device)
            return x
        # if first time, gotta record the corrupted outputs (to then put them in later)
        if first_pass:
            return x
        # we are here if it is the second pass
        # now, we gotta use the clean outputs, except for the states we wanna keep corrupted
        h = untuple(x)
        for t in corr_spec.get(layer, []):
            h[1:, t] = untuple(first_pass_trace[layer].output)[1:, t]
        return x

    # With the patching rules defined, run the patched model in inference.
    additional_layers = [] if trace_layers is None else trace_layers
    for first_pass in [True, False]:
        with torch.no_grad(), nethook.TraceDict(
            model,
            [embed_layername] + list(corr_spec.keys()) + additional_layers,
            edit_output=corr_rep,
        ) as td:
            outputs_exp = model(**inp)
            if first_pass:
                first_pass_trace = td

    # We report softmax probabilities for the answers_t token predictions of interest.
    probs = torch.softmax(outputs_exp.logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]

    # If tracing all layers, collect all activations together to return.
    if trace_layers is not None:
        all_traced = torch.stack(
            [untuple(td[layer].output).detach().cpu() for layer in trace_layers], dim=2
        )
        return probs, all_traced

    return probs

# %%
# handle between the two
def trace_direct_or_indirect(
    model,  # The model
    inp,  # A set of inputs
    states_to_corrupt,  # A list of (token index, layername) triples to corrupt
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    trace_layers=None,  # List of traced outputs to return
    direct=False,
):
  if direct:
    return trace_with_corrupt(model, inp, states_to_corrupt, answers_t, tokens_to_mix, noise, trace_layers)
  else:
    return trace_with_patch(model, inp, states_to_corrupt, answers_t, tokens_to_mix, noise, trace_layers)

# %% [markdown]
# ## Scanning all locations
#
# A causal flow heatmap is created by repeating `trace_with_patch` at every individual hidden state, and measuring the impact of restoring state at each location.
#
# The `calculate_hidden_flow` function does this loop.  It handles both the case of restoring a single hidden state, and also restoring MLP or attention states.  Because MLP and attention make small residual contributions, to observe a causal effect in those cases, we need to restore several layers of contributions at once, which is done by `trace_important_window`.

# %%
def calculate_hidden_flow(
    mt, prompt, subject, samples=10, noise=0.1, window=10, kind=None, direct=False,
):
    """
    Runs causal tracing over every token/layer combination in the network
    and returns a dictionary numerically summarizing the results.
    """
    inp = make_inputs(mt.tokenizer, [prompt] * (samples + 1))
    with torch.no_grad():
        answer_t, base_score = [d[0] for d in predict_from_input(mt.model, inp)]
    [answer] = decode_tokens(mt.tokenizer, [answer_t])
    e_range = find_token_range(mt.tokenizer, inp["input_ids"][0], subject)
    low_score = trace_direct_or_indirect(
            mt.model, inp, [], answer_t, e_range, noise=noise, direct=direct,
        ).item()
    if not kind:
        differences = trace_important_states(
            mt.model, mt.num_layers, inp, e_range, answer_t, noise=noise, direct=direct,
        )
    else:
        differences = trace_important_window(
            mt.model,
            mt.num_layers,
            inp,
            e_range,
            answer_t,
            noise=noise,
            window=window,
            kind=kind,
            direct=direct,
        )
    differences = differences.detach().cpu()
    return dict(
        scores=differences,
        low_score=low_score,
        high_score=base_score,
        input_ids=inp["input_ids"][0],
        input_tokens=decode_tokens(mt.tokenizer, inp["input_ids"][0]),
        subject_range=e_range,
        answer=answer,
        window=window,
        kind=kind or "",
    )


def trace_important_states(model, num_layers, inp, e_range, answer_t, noise=0.1, direct=False):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in range(ntoks):
        row = []
        for layer in range(0, num_layers):
            r = trace_direct_or_indirect(
                model,
                inp,
                [(tnum, layername(model, layer))],
                answer_t,
                tokens_to_mix=e_range,
                noise=noise,
                direct=direct
            )
            if str(r.device).startswith("mps"): # fix bug of M1
                row.append(r.cpu())
            else:
                row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)


def trace_important_window(
    model, num_layers, inp, e_range, answer_t, kind, window=10, noise=0.1, direct=False,
):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in range(ntoks):
        row = []
        for layer in range(0, num_layers):
            layerlist = [
                (tnum, layername(model, L, kind))
                for L in range(
                    max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
                )
            ]
            r = trace_direct_or_indirect(model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise, direct=direct)
            if str(r.device).startswith("mps"): # fix bug of M1
                row.append(r.cpu())
            else:
                row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)

# %% [markdown]
# ## Plotting the results
#
# The `plot_trace_heatmap` function draws the data on a heatmap.  That function is not shown here; it is in `experiments.causal_trace`.

# %%
def plot_hidden_flow(
    mt,
    prompt,
    subject=None,
    samples=10,
    noise=0.1,
    window=10,
    kind=None,
    modelname=None,
    savepdf=None,
    direct=False,
):
    if subject is None:
        subject = guess_subject(prompt)
    result = calculate_hidden_flow(
        mt, prompt, subject, samples=samples, noise=noise, window=window, kind=kind, direct=direct,
    )
    plot_trace_heatmap(result, savepdf, modelname=modelname, direct=direct)


def plot_all_flow(mt, prompt, subject=None, noise=0.1, modelname=None, direct=False):
    for kind in [None, "mlp", "attn"]:
        plot_hidden_flow(
            mt, prompt, subject, modelname=modelname, noise=noise, kind=kind, direct=direct
        )

# %% [markdown]
# The following prompt can be changed to any factual statement to trace.

# %%
plot_all_flow(mt, "The Space Needle is in the city of", noise=noise_level, direct=True)
plot_all_flow(mt, "The Space Needle is in the city of", noise=noise_level, direct=False)

# %% [markdown]
# Here we trace a few more factual statements from a file of test cases.

# %%
for knowledge in knowns[:5]:
    plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level, direct=True)
    plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level, direct=False)
# Out:
# first_pass True
# pass: True tensor([-86.7169, -80.9892, -77.7348, -85.0083, -80.1871, -82.7938, -84.0299,
#         -86.8166, -76.8988, -83.2094, -92.6465], device='mps:0')
# first_pass False
# pass: False tensor([-86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169,
#         -86.7169, -86.7169, -86.7169, -86.7169], device='mps:0')
# finally tensor([-86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169,
#         -86.7169, -86.7169, -86.7169, -86.7169], device='mps:0')
# tensor(0.0765, device='mps:0')
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# first_pass True
# pass: True tensor([-86.7169, -80.9892, -77.7348, -85.0083, -80.1871, -82.7938, -84.0299,
#         -86.8166, -76.8988, -83.2094, -92.6465], device='mps:0')
# first_pass False
# pass: False tensor([-86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169,
#         -86.7169, -86.7169, -86.7169, -86.7169], device='mps:0')
# finally tensor([-86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169,
#         -86.7169, -86.7169, -86.7169, -86.7169], device='mps:0')
# tensor(0.0765, device='mps:0')
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# first_pass True
# pass: True tensor([-86.7169, -80.9892, -77.7348, -85.0083, -80.1871, -82.7938, -84.0299,
#         -86.8166, -76.8988, -83.2094, -92.6465], device='mps:0')
# first_pass False
# pass: False tensor([-86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169,
#         -86.7169, -86.7169, -86.7169, -86.7169], device='mps:0')
# finally tensor([-86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169, -86.7169,
#         -86.7169, -86.7169, -86.7169, -86.7169], device='mps:0')
# tensor(0.0765, device='mps:0')
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# torch.Size([11, 10, 50257])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/pj/7c8cmyxs3dx4svfsvz4q75s00000gn/T/ipykernel_71554/442169475.py in <module>
#       1 for knowledge in knowns[:5]:
#       2     plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level, direct=True)
# ----> 3     plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level, direct=False)
#
# /var/folders/pj/7c8cmyxs3dx4svfsvz4q75s00000gn/T/ipykernel_71554/4082440545.py in plot_all_flow(mt, prompt, subject, noise, modelname, direct)
#      21 def plot_all_flow(mt, prompt, subject=None, noise=0.1, modelname=None, direct=False):
#      22     for kind in [None, "mlp", "attn"]:
# ---> 23         plot_hidden_flow(
#      24             mt, prompt, subject, modelname=modelname, noise=noise, kind=kind, direct=direct
#      25         )
#
# /var/folders/pj/7c8cmyxs3dx4svfsvz4q75s00000gn/T/ipykernel_71554/4082440545.py in plot_hidden_flow(mt, prompt, subject, samples, noise, window, kind, modelname, savepdf, direct)
#      13     if subject is None:
#      14         subject = guess_subject(prompt)
# ---> 15     result = calculate_hidden_flow(
#      16         mt, prompt, subject, samples=samples, noise=noise, window=window, kind=kind, direct=direct,
#      17     )
#
# /var/folders/pj/7c8cmyxs3dx4svfsvz4q75s00000gn/T/ipykernel_71554/2327897087.py in calculate_hidden_flow(mt, prompt, subject, samples, noise, window, kind, direct)
#      24         )
#      25     else:
# ---> 26         differences = trace_important_window(
#      27             mt.model,
#      28             mt.num_layers,
#
# /var/folders/pj/7c8cmyxs3dx4svfsvz4q75s00000gn/T/ipykernel_71554/2327897087.py in trace_important_window(model, num_layers, inp, e_range, answer_t, kind, window, noise)
#      84                 )
#      85             ]
# ---> 86             r = trace_with_patch(
#      87                 model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise
#      88             )
#
# /var/folders/pj/7c8cmyxs3dx4svfsvz4q75s00000gn/T/ipykernel_71554/4107994557.py in trace_with_patch(model, inp, states_to_patch, answers_t, tokens_to_mix, noise, trace_layers)
#      45         edit_output=patch_rep,
#      46     ) as td:
# ---> 47         outputs_exp = model(**inp)
#      48
#      49     # We report softmax probabilities for the answers_t token predictions of interest.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1044         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1045
# -> 1046         transformer_outputs = self.transformer(
#    1047             input_ids,
#    1048             past_key_values=past_key_values,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     887                 )
#     888             else:
# --> 889                 outputs = block(
#     890                     hidden_states,
#     891                     layer_past=layer_past,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     423
#     424         residual = hidden_states
# --> 425         hidden_states = self.ln_2(hidden_states)
#     426         feed_forward_hidden_states = self.mlp(hidden_states)
#     427         # residual connection
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/normalization.py in forward(self, input)
#     188
#     189     def forward(self, input: Tensor) -> Tensor:
# --> 190         return F.layer_norm(
#     191             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     192
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2513             layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2514         )
# -> 2515     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2516
#    2517
#
# KeyboardInterrupt:
